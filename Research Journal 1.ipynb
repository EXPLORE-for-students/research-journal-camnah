# %% [markdown]
# # Research Notebook
# ## Camila Guzman
# ## Date: Jan 27th 2024

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# - I worked on learning how to run Python on Niagara's supercomputer using my Windows terminal.
# - I learned to use FileZilla to see my outputs.
#
# ## Motivation:
#
# I need to understand how to use the supercomputer and run simulations. That requires me to become familiar with the necessary commands, and be able to analyze data on my Windows terminal using Python.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# Professor Kannan shared a piece of code that contained public data of galaxies. He asked us to plot the stellar mass vs the black hole mass, and compare the results with Pacucci's paper, "The Redshift Evolution of the M •–M ⋆ Relation for JWST's Supermassive Black Holes at z > 4", that contained the same analysis. The goal was to undertand how to copy his code and paste it on our directories so that we can activate our environment and run python through it.

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# I was able to edit his code using vim, I was also able to run it and open the plot using FileZilla. However, it seems it isn't correct since I am missing data in my plot.
#
# Steps used to get my plot:
#
# 1. Log in to Niagara
# 2. Get to the code template using "cd /scratch/k/kannanr/kannanr/Blackholes/analysis"
# 3. Copy the code and paste it on my directory "cp /scratch/k/kan/kan/bh/analysis/readbh.py ." on "/scratch/k/kannanr/camila03".
# 4. Create an environment called "env" by using "python -m venv env"
# 5. Activate the environment using "source env/bin/activate"
# 6. Open vim and edit the code using "vim read_BH_mass.py"
#
# Figure 1 shows my code:
# ![image-3.png](attachment:image-3.png)
#
# 7. Save code and then run it by typing "python read_BH_mass.py"
# 8. Connect my SSH account to FileZilla and download it to my computer.
#
# Figure 2 shows my plot:
# ![image.png](attachment:image.png)
#
# Figure 3 shows the paper's graph:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# - See if I can fix my graph, add the local relation lines to it as well.
# - Use different sets of data to create multiple graphs and familiarize myself with the enviroment I am working on.
# - Try to run my first simulation

# %% [markdown]
# # 5. Bibliography
#
# Pacucci, F., & Loeb, A. (2024, April). The redshift evolution of the M •–m ⋆ relation for JWST’s supermassive black holes at Z &gt; 4. NASA/ADS. https://ui.adsabs.harvard.edu/abs/2024ApJ...964..154P/abstract
