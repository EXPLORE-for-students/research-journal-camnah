# %% [markdown]
# # Research Notebook
# ## Camila Guzman
# ## Date: Jan 24, 2025

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# I was able to familiarize myself with running Python on Niagara's supercomputer via my Windows terminal, update my previous code, run my first simulation, and begin adjusting parameters on my simulation to compare the various outputs with my group members.
#
# ## Motivation:
#
# We are trying to find a simulation that can explain the observations from JWST, which detected super-massive black holes at redshifts greater than 4. This detection shows that their mass is 10 to 100 times larger than expected [1]. We need high resolution simulations in order to compare our results with observational values. However, we need to start with low resolution simulations first, and learn to make our own simulation code.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# - 1. Fixed my code from my previous results: after contacting my Junior Mentor, we found that the issue was that the Python version I was using had trouble working with Matplotlib. After installing python3.11, I ran Professor Kannan's code:
#
# ![image-2.png](attachment:image-2.png)
# ![image-5.png](attachment:image-5.png)
#
# - 2. I created my own code that would grab data from The IllustrisTNG Project and plotted different relationships (I did not save my code unfortunately, but it was similar to the one provided by Professor Kannan).
#
# - 3. I ran my first low resolution simulation and wrote a code that would grab the results and plot the same graphs as before to compare:
#
# Code used:
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#
# - 4. I ran the same simulation but I changed the BlackHoleEddingtonFactor parameter from 1 to 2. We know that this theoretical limit is applied to simulations, however, since it has been observed that some super-massive blackholes exceed this limit, we wanted to check if increasing this limit would bring different results. Every person in the group chose a different factor, I got to increased it from 1 to 2.

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# - 1. ![image.png](attachment:image.png)
#
# This plot shows how the blackhole mass increases as the stellar mass of the high redshift galaxy increases. However, there are two paths shown in this graph. This suggests that there are two different ways a galaxy could evolve.
#
# - 2.
# ![image-2.png](attachment:image-2.png)
#
# As the mass of the black hole increases, the gas mass increases. However, the gass mass starts to saturate at 10^11 solar masses. This indicates that smaller black holes have more varied gas masses, while larger ones have a more stable gas mass.
#
# ![image-3.png](attachment:image-3.png)
#
# This plot shows that galaxies with higher stellar mass generally have higher gas mass. There seems to be a limit of gass mass at 10^11 solar masses, which could result from the presence of AGNs preventing unlimited gas accumulation.
#
# ![image-4.png](attachment:image-4.png)
# This plot shows that more massive galaxies have higher metallicities. At higher stellar masses we can see that there is less variation. This could indicate that massive galaxies retain more metals.
#
# ![image-5.png](attachment:image-5.png)
# This plot shows that more massive galaxies have higher star formation activity. The spread of formation rate is less varied at higher stellar masses, indicating that massive galaxies might have a more stable stellar formation rate.
#
# These plots were in agreement with my group members' results. They all follow the expected relationship.
#
# - 3.
# ![image-6.png](attachment:image-6.png)
# ![image-9.png](attachment:image-9.png)
# ![image-8.png](attachment:image-8.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#
# We can see that there are fewer points since it is a low resolution simulation. However, they are similar to the previous graphs I plotted in part 2.
#
# - 4. I ran the simulation with a different parameter and the results were exactly the same. I would need to compare results with my group on the next meeting.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# Next thing is to learn how to write my own simulation code:
#
# I need to read about GADGET-4 and get my own code and talk to Professor Kannan about the necessary adjustments to run my simulation code.

# %% [markdown]
# # 5. Bibliography
#
# [1]. Pacucci, F., & Loeb, A. (2024, April). The redshift evolution of the M •–m ⋆ relation for JWST’s supermassive black holes at Z > 4. NASA/ADS. https://ui.adsabs.harvard.edu/abs/2024ApJ...964..154P/abstract
